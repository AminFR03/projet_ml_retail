# %% [markdown]
# # Exploration and Prototyping
# This notebook is used for initial data exploration, visualization, and prototyping models.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('../data/raw/dataset.csv')
df.head()

# %%
df.describe()
